# %%
import pandas as pd

# Load a Parquet file (or directory of files)
df = pd.read_parquet("data/delta/patients_transformed")

# Use pandas for querying
df.head(20)
# Out:
#     PatientId PatientName              City PostCode        Disease  \
# 0           1       XXXXX         Worcester      WR2         Cancer
# 1           2       XXXXX        Harborough      LE7         Cancer
# 2           3       XXXXX           Croydon      CR9     Depression
# 3           4       XXXXX            Exeter      EX4       Diabetes
# 4           5       XXXXX  Bristol, City of      BS2   Hypertension
# 5           6       XXXXX         Southwark     SE15         Cancer
# 6           7       XXXXX            Barnet       N2       Diabetes
# 7           8       XXXXX        Manchester      M11       Diabetes
# 8           9       XXXXX          Bridgend     CF34   Hypertension
# 9          10       XXXXX         Leicester      LE5     Depression
# 10         11       XXXXX          Tendring      CO7       Diabetes
# 11         12       XXXXX           Burnley     BB11       Diabetes
# 12         13       XXXXX        Birmingham      B29  Schizophrenia
# ...
